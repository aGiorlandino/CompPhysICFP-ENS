# %% [markdown]
# # Faster than the clock algorithms
#
# Faster than the clock algorithms are useful in cases when the acceptance rate of the standard Monte Carlo is low. An example of this is the Ising model at low temperatures, when we are disregarding most of the moves. The idea of the faster than the clock algorithms is to speed up the simulation by calculating the probability distribution of the number of moves that will be required in order to change the state of the system. Then, only accepted moves need to be evaluated during the simulation. One just has to properly generate the times between two of these accepted moves.

# %% [markdown]
# ## Random depositions
#
# Let's consider the problem of random depositions in one dimension. Consider the line of length $L$ on which we are randomly depositing  pins of width $2 \times \sigma$ on the interval $[\sigma,L-\sigma]$ which cannot overlap. At time $t=1$ we deposit the first pin and in succesive time steps we try to deposite further pins. We make the deposition if the move is allowed, otherwise we choose a new position etc. The process halts when no further pins can be deposited.
#
# <br>
# <table><tr style="background-color: white;">
# <td> <img src="https://gist.github.com/mferrero/ae328ab0e3a0d3d7181a007daf5a373a/raw/clothes_pins_many.png" width=500 height=150 /> </td>
# <td> <img src="https://gist.github.com/mferrero/ae328ab0e3a0d3d7181a007daf5a373a/raw/clothes_pins_single.png" width=200 height=150 /> </td>
# </tr></table>
# <br>
#
# In the following, we will write two Monte Carlo algorithms to simulate random depositions, a direct real-time implementation and a faster than the clock implementation. Results will be compared with the analytical solution.
#
# We first import the necessary libraries

# %%
import numpy as np
import bisect
import matplotlib.pylab as plt

# %% [markdown]
# ## Real time algorithm
#
# Write the random depositions algorithm in real time, which outputs the times at which the depositions are made.
# You can use pins with $\sigma = 1$. Start with $L = 100$ and increase to $L = 10000$ to see how the
# simulation time changes.
#
# Hint: It is a good idea to encode the positions of the pins in an *ordered* list. You can then use bisection to quickly find where a new pin has to be inserted. This example shows how to use the `bisect` function
# ```python
# pins = [1, 4, 6, 7, 10, 16]
# ind = bisect.bisect(pins, 9) # find where 9 would go
# pins.insert(ind, 9) # insert 9 in the right place
# print(pins)
# ```

# %%
# parameters
sigma = 1
L = 10000
np.random.seed(9827)

# initialize variables
pins = [-sigma, L+sigma] # two fake pins
time = 0

# main loop
while(True):
    
    time += 1
    r = np.random.uniform(sigma, L-sigma)
    ind = bisect.bisect(pins, r)
    
    # distance to neighbors
    dist_r = pins[ind] - r
    dist_l = r - pins[ind-1]
    
    # there is enough space
    if dist_r >= 2*sigma and dist_l >= 2*sigma:

        # insert pin
        pins.insert(ind, r)

        # is there still some space somewhere?
        pin_array = np.array(pins)
        n = len(pins)
        intervals = pin_array[1:n] - pin_array[0:n-1]
        available = np.any(intervals > 4 * sigma)
        n_available = np.sum(intervals > 4 * sigma)
        
        print("time = ", time, "# pins = ", n-2, "# available = ", n_available)
        
        # stop if no space left
        if not available: break
        
            
print("Density = ", (len(pins)-2) * 2 * sigma / L)
# Out:
# time =  1 # pins =  1 # available =  2
# time =  2 # pins =  2 # available =  3
# time =  3 # pins =  3 # available =  4
# time =  4 # pins =  4 # available =  5
# time =  5 # pins =  5 # available =  6
# time =  6 # pins =  6 # available =  7
# time =  7 # pins =  7 # available =  8
# time =  8 # pins =  8 # available =  9
# time =  9 # pins =  9 # available =  10
# time =  10 # pins =  10 # available =  11
# time =  11 # pins =  11 # available =  12
# time =  12 # pins =  12 # available =  13
# time =  13 # pins =  13 # available =  14
# time =  14 # pins =  14 # available =  15
# time =  15 # pins =  15 # available =  16
# time =  16 # pins =  16 # available =  17
# time =  17 # pins =  17 # available =  18
# time =  18 # pins =  18 # available =  19
# time =  19 # pins =  19 # available =  20
# time =  20 # pins =  20 # available =  21
# time =  21 # pins =  21 # available =  22
# time =  22 # pins =  22 # available =  23
# time =  23 # pins =  23 # available =  24
# time =  24 # pins =  24 # available =  25
# time =  25 # pins =  25 # available =  26
# time =  26 # pins =  26 # available =  27
# time =  27 # pins =  27 # available =  28
# time =  28 # pins =  28 # available =  29
# time =  29 # pins =  29 # available =  30
# time =  30 # pins =  30 # available =  31
# time =  31 # pins =  31 # available =  32
# time =  32 # pins =  32 # available =  33
# time =  33 # pins =  33 # available =  34
# time =  34 # pins =  34 # available =  35
# time =  35 # pins =  35 # available =  36
# time =  36 # pins =  36 # available =  37
# time =  37 # pins =  37 # available =  38
# time =  38 # pins =  38 # available =  39
# time =  39 # pins =  39 # available =  40
# time =  40 # pins =  40 # available =  41
# time =  41 # pins =  41 # available =  42
# time =  42 # pins =  42 # available =  43
# time =  43 # pins =  43 # available =  44
# time =  44 # pins =  44 # available =  45
# time =  45 # pins =  45 # available =  46
# time =  46 # pins =  46 # available =  47
# time =  47 # pins =  47 # available =  48
# time =  48 # pins =  48 # available =  49
# time =  49 # pins =  49 # available =  50
# time =  50 # pins =  50 # available =  51
# time =  51 # pins =  51 # available =  52
# time =  52 # pins =  52 # available =  53
# time =  53 # pins =  53 # available =  54
# time =  54 # pins =  54 # available =  55
# time =  55 # pins =  55 # available =  56
# time =  56 # pins =  56 # available =  57
# time =  57 # pins =  57 # available =  58
# time =  58 # pins =  58 # available =  59
# time =  59 # pins =  59 # available =  60
# time =  60 # pins =  60 # available =  61
# time =  62 # pins =  61 # available =  62
# time =  63 # pins =  62 # available =  63
# time =  64 # pins =  63 # available =  64
# time =  65 # pins =  64 # available =  65
# time =  66 # pins =  65 # available =  66
# time =  67 # pins =  66 # available =  67
# time =  68 # pins =  67 # available =  68
# time =  69 # pins =  68 # available =  69
# time =  70 # pins =  69 # available =  70
# time =  71 # pins =  70 # available =  71
# time =  72 # pins =  71 # available =  72
# time =  73 # pins =  72 # available =  73
# time =  74 # pins =  73 # available =  74
# time =  75 # pins =  74 # available =  75
# time =  76 # pins =  75 # available =  76
# time =  77 # pins =  76 # available =  77
# time =  78 # pins =  77 # available =  78
# time =  79 # pins =  78 # available =  79
# time =  80 # pins =  79 # available =  80
# time =  81 # pins =  80 # available =  81
# time =  82 # pins =  81 # available =  82
# time =  83 # pins =  82 # available =  83
# time =  84 # pins =  83 # available =  84
# time =  85 # pins =  84 # available =  85
# time =  86 # pins =  85 # available =  86
# time =  87 # pins =  86 # available =  87
# time =  88 # pins =  87 # available =  88
# time =  89 # pins =  88 # available =  88
# time =  90 # pins =  89 # available =  89
# time =  91 # pins =  90 # available =  90
# time =  92 # pins =  91 # available =  91
# time =  93 # pins =  92 # available =  92
# time =  94 # pins =  93 # available =  93
# time =  95 # pins =  94 # available =  94
# time =  96 # pins =  95 # available =  95
# time =  97 # pins =  96 # available =  96
# time =  98 # pins =  97 # available =  97
# time =  100 # pins =  98 # available =  98
# time =  101 # pins =  99 # available =  99
# time =  102 # pins =  100 # available =  100
# time =  103 # pins =  101 # available =  101
# time =  105 # pins =  102 # available =  102
# time =  106 # pins =  103 # available =  103
# time =  109 # pins =  104 # available =  104
# time =  110 # pins =  105 # available =  105
# time =  112 # pins =  106 # available =  106
# time =  113 # pins =  107 # available =  107
# time =  114 # pins =  108 # available =  108
# time =  115 # pins =  109 # available =  109
# time =  116 # pins =  110 # available =  110
# time =  117 # pins =  111 # available =  111
# time =  118 # pins =  112 # available =  112
# time =  119 # pins =  113 # available =  113
# time =  120 # pins =  114 # available =  114
# time =  121 # pins =  115 # available =  115
# time =  122 # pins =  116 # available =  115
# time =  123 # pins =  117 # available =  116
# time =  124 # pins =  118 # available =  117
# time =  125 # pins =  119 # available =  118
# time =  126 # pins =  120 # available =  119
# time =  127 # pins =  121 # available =  120
# time =  128 # pins =  122 # available =  121
# time =  129 # pins =  123 # available =  122
# time =  130 # pins =  124 # available =  123
# time =  131 # pins =  125 # available =  124
# time =  132 # pins =  126 # available =  125
# time =  133 # pins =  127 # available =  126
# time =  134 # pins =  128 # available =  127
# time =  135 # pins =  129 # available =  128
# time =  136 # pins =  130 # available =  129
# time =  137 # pins =  131 # available =  130
# time =  139 # pins =  132 # available =  131
# time =  140 # pins =  133 # available =  132
# time =  141 # pins =  134 # available =  133
# time =  142 # pins =  135 # available =  134
# time =  143 # pins =  136 # available =  135
# time =  144 # pins =  137 # available =  136
# time =  145 # pins =  138 # available =  137
# time =  146 # pins =  139 # available =  138
# time =  147 # pins =  140 # available =  139
# time =  148 # pins =  141 # available =  140
# time =  149 # pins =  142 # available =  141
# time =  150 # pins =  143 # available =  142
# time =  152 # pins =  144 # available =  143
# time =  153 # pins =  145 # available =  144
# time =  154 # pins =  146 # available =  145
# time =  155 # pins =  147 # available =  146
# time =  156 # pins =  148 # available =  147
# time =  157 # pins =  149 # available =  148
# time =  158 # pins =  150 # available =  149
# time =  159 # pins =  151 # available =  150
# time =  160 # pins =  152 # available =  151
# time =  161 # pins =  153 # available =  152
# time =  162 # pins =  154 # available =  153
# time =  163 # pins =  155 # available =  154
# time =  164 # pins =  156 # available =  155
# time =  165 # pins =  157 # available =  156
# time =  166 # pins =  158 # available =  157
# time =  167 # pins =  159 # available =  158
# time =  168 # pins =  160 # available =  159
# time =  169 # pins =  161 # available =  160
# time =  170 # pins =  162 # available =  161
# time =  171 # pins =  163 # available =  162
# time =  172 # pins =  164 # available =  163
# time =  174 # pins =  165 # available =  164
# time =  176 # pins =  166 # available =  165
# time =  177 # pins =  167 # available =  166
# time =  179 # pins =  168 # available =  167
# time =  181 # pins =  169 # available =  168
# time =  182 # pins =  170 # available =  169
# time =  184 # pins =  171 # available =  170
# time =  185 # pins =  172 # available =  171
# time =  186 # pins =  173 # available =  172
# time =  187 # pins =  174 # available =  173
# time =  188 # pins =  175 # available =  174
# time =  189 # pins =  176 # available =  175
# time =  190 # pins =  177 # available =  175
# time =  191 # pins =  178 # available =  176
# time =  192 # pins =  179 # available =  177
# time =  193 # pins =  180 # available =  178
# time =  194 # pins =  181 # available =  178
# time =  195 # pins =  182 # available =  178
# time =  196 # pins =  183 # available =  179
# time =  197 # pins =  184 # available =  180
# time =  198 # pins =  185 # available =  181
# time =  199 # pins =  186 # available =  182
# time =  201 # pins =  187 # available =  183
# time =  202 # pins =  188 # available =  184
# time =  204 # pins =  189 # available =  185
# time =  205 # pins =  190 # available =  186
# time =  206 # pins =  191 # available =  187
# time =  207 # pins =  192 # available =  188
# time =  208 # pins =  193 # available =  189
# time =  210 # pins =  194 # available =  190
# time =  211 # pins =  195 # available =  191
# time =  213 # pins =  196 # available =  192
# time =  214 # pins =  197 # available =  193
# time =  215 # pins =  198 # available =  194
# time =  216 # pins =  199 # available =  195
# time =  217 # pins =  200 # available =  196
# time =  218 # pins =  201 # available =  197
# time =  220 # pins =  202 # available =  198
# time =  221 # pins =  203 # available =  199
# time =  222 # pins =  204 # available =  200
# time =  223 # pins =  205 # available =  201
# time =  224 # pins =  206 # available =  202
# time =  225 # pins =  207 # available =  203
# time =  226 # pins =  208 # available =  204
# time =  227 # pins =  209 # available =  204
# time =  228 # pins =  210 # available =  205
# time =  229 # pins =  211 # available =  206
# time =  230 # pins =  212 # available =  207
# time =  232 # pins =  213 # available =  208
# time =  233 # pins =  214 # available =  209
# time =  235 # pins =  215 # available =  210
# time =  236 # pins =  216 # available =  211
# time =  237 # pins =  217 # available =  212
# time =  238 # pins =  218 # available =  213
# time =  239 # pins =  219 # available =  214
# time =  240 # pins =  220 # available =  215
# time =  241 # pins =  221 # available =  216
# time =  242 # pins =  222 # available =  217
# time =  245 # pins =  223 # available =  218
# time =  246 # pins =  224 # available =  219
# time =  247 # pins =  225 # available =  220
# time =  248 # pins =  226 # available =  221
# time =  249 # pins =  227 # available =  222
# time =  250 # pins =  228 # available =  223
# time =  251 # pins =  229 # available =  224
# time =  253 # pins =  230 # available =  225
# time =  254 # pins =  231 # available =  226
# time =  255 # pins =  232 # available =  227
# time =  256 # pins =  233 # available =  228
# time =  257 # pins =  234 # available =  228
# time =  258 # pins =  235 # available =  229
# time =  259 # pins =  236 # available =  230
# time =  260 # pins =  237 # available =  231
# time =  262 # pins =  238 # available =  232
# time =  263 # pins =  239 # available =  233
# time =  264 # pins =  240 # available =  234
# time =  265 # pins =  241 # available =  235
# time =  266 # pins =  242 # available =  236
# time =  268 # pins =  243 # available =  237
# time =  269 # pins =  244 # available =  238
# time =  271 # pins =  245 # available =  238
# time =  272 # pins =  246 # available =  239
# time =  273 # pins =  247 # available =  239
# time =  274 # pins =  248 # available =  240
# time =  275 # pins =  249 # available =  241
# time =  277 # pins =  250 # available =  242
# time =  278 # pins =  251 # available =  243
# time =  280 # pins =  252 # available =  244
# time =  281 # pins =  253 # available =  245
# time =  282 # pins =  254 # available =  245
# time =  283 # pins =  255 # available =  246
# time =  284 # pins =  256 # available =  247
# time =  285 # pins =  257 # available =  247
# time =  286 # pins =  258 # available =  248
# time =  287 # pins =  259 # available =  248
# time =  288 # pins =  260 # available =  249
# time =  289 # pins =  261 # available =  250
# time =  290 # pins =  262 # available =  251
# time =  291 # pins =  263 # available =  252
# time =  292 # pins =  264 # available =  253
# time =  293 # pins =  265 # available =  254
# time =  294 # pins =  266 # available =  255
# time =  295 # pins =  267 # available =  255
# time =  296 # pins =  268 # available =  256
# time =  297 # pins =  269 # available =  257
# time =  298 # pins =  270 # available =  257
# time =  299 # pins =  271 # available =  258
# time =  300 # pins =  272 # available =  259
# time =  301 # pins =  273 # available =  260
# time =  302 # pins =  274 # available =  261
# time =  303 # pins =  275 # available =  261
# time =  304 # pins =  276 # available =  262
# time =  305 # pins =  277 # available =  263
# time =  306 # pins =  278 # available =  264
# time =  307 # pins =  279 # available =  265
# time =  308 # pins =  280 # available =  266
# time =  309 # pins =  281 # available =  267
# time =  310 # pins =  282 # available =  268
# time =  311 # pins =  283 # available =  269
# time =  312 # pins =  284 # available =  270
# time =  313 # pins =  285 # available =  271
# time =  314 # pins =  286 # available =  272
# time =  315 # pins =  287 # available =  273
# time =  316 # pins =  288 # available =  274
# time =  318 # pins =  289 # available =  275
# time =  319 # pins =  290 # available =  276
# time =  320 # pins =  291 # available =  277
# time =  321 # pins =  292 # available =  278
# time =  322 # pins =  293 # available =  278
# time =  323 # pins =  294 # available =  279
# time =  324 # pins =  295 # available =  280
# time =  325 # pins =  296 # available =  280
# time =  326 # pins =  297 # available =  281
# time =  327 # pins =  298 # available =  282
# time =  329 # pins =  299 # available =  283
# time =  330 # pins =  300 # available =  284
# time =  331 # pins =  301 # available =  285
# time =  332 # pins =  302 # available =  286
# time =  334 # pins =  303 # available =  287
# time =  335 # pins =  304 # available =  288
# time =  336 # pins =  305 # available =  289
# time =  337 # pins =  306 # available =  290
# time =  338 # pins =  307 # available =  291
# time =  339 # pins =  308 # available =  291
# time =  340 # pins =  309 # available =  292
# time =  341 # pins =  310 # available =  293
# time =  342 # pins =  311 # available =  293
# time =  343 # pins =  312 # available =  294
# time =  344 # pins =  313 # available =  295
# time =  345 # pins =  314 # available =  296
# time =  346 # pins =  315 # available =  297
# time =  347 # pins =  316 # available =  298
# time =  348 # pins =  317 # available =  299
# time =  349 # pins =  318 # available =  300
# time =  350 # pins =  319 # available =  300
# time =  352 # pins =  320 # available =  301
# time =  353 # pins =  321 # available =  302
# time =  355 # pins =  322 # available =  303
# time =  356 # pins =  323 # available =  304
# time =  357 # pins =  324 # available =  305
# time =  358 # pins =  325 # available =  306
# time =  359 # pins =  326 # available =  307
# time =  360 # pins =  327 # available =  308
# time =  361 # pins =  328 # available =  309
# time =  362 # pins =  329 # available =  310
# time =  363 # pins =  330 # available =  311
# time =  364 # pins =  331 # available =  312
# time =  365 # pins =  332 # available =  313
# time =  366 # pins =  333 # available =  314
# time =  367 # pins =  334 # available =  315
# time =  368 # pins =  335 # available =  316
# time =  370 # pins =  336 # available =  317
# time =  371 # pins =  337 # available =  318
# time =  372 # pins =  338 # available =  319
# time =  373 # pins =  339 # available =  320
# time =  374 # pins =  340 # available =  321
# time =  375 # pins =  341 # available =  322
# time =  376 # pins =  342 # available =  323
# time =  378 # pins =  343 # available =  324
# time =  379 # pins =  344 # available =  325
# time =  380 # pins =  345 # available =  326
# time =  381 # pins =  346 # available =  326
# time =  382 # pins =  347 # available =  326
# time =  383 # pins =  348 # available =  327
# time =  384 # pins =  349 # available =  328
# time =  385 # pins =  350 # available =  329
# time =  386 # pins =  351 # available =  330
# time =  387 # pins =  352 # available =  331
# time =  388 # pins =  353 # available =  332
# time =  389 # pins =  354 # available =  333
# time =  390 # pins =  355 # available =  334
# time =  391 # pins =  356 # available =  335
# time =  392 # pins =  357 # available =  336
# time =  393 # pins =  358 # available =  337
# time =  395 # pins =  359 # available =  338
# time =  396 # pins =  360 # available =  339
# time =  397 # pins =  361 # available =  340
# time =  398 # pins =  362 # available =  341
# time =  399 # pins =  363 # available =  342
# time =  400 # pins =  364 # available =  343
# time =  402 # pins =  365 # available =  343
# time =  403 # pins =  366 # available =  344
# time =  404 # pins =  367 # available =  345
# time =  406 # pins =  368 # available =  346
# time =  407 # pins =  369 # available =  347
# time =  408 # pins =  370 # available =  348
# time =  409 # pins =  371 # available =  349
# time =  410 # pins =  372 # available =  350
# time =  411 # pins =  373 # available =  351
# time =  412 # pins =  374 # available =  352
# time =  413 # pins =  375 # available =  353
# time =  414 # pins =  376 # available =  354
# time =  415 # pins =  377 # available =  355
# time =  416 # pins =  378 # available =  356
# time =  417 # pins =  379 # available =  357
# time =  418 # pins =  380 # available =  357
# time =  419 # pins =  381 # available =  358
# time =  420 # pins =  382 # available =  359
# time =  421 # pins =  383 # available =  360
# time =  422 # pins =  384 # available =  361
# time =  423 # pins =  385 # available =  362
# time =  424 # pins =  386 # available =  363
# time =  425 # pins =  387 # available =  364
# time =  426 # pins =  388 # available =  365
# time =  427 # pins =  389 # available =  366
# time =  428 # pins =  390 # available =  367
# time =  429 # pins =  391 # available =  368
# time =  430 # pins =  392 # available =  369
# time =  431 # pins =  393 # available =  370
# time =  434 # pins =  394 # available =  371
# time =  435 # pins =  395 # available =  372
# time =  436 # pins =  396 # available =  373
# time =  437 # pins =  397 # available =  374
# time =  438 # pins =  398 # available =  375
# time =  439 # pins =  399 # available =  376
# time =  440 # pins =  400 # available =  377
# time =  441 # pins =  401 # available =  378
# time =  442 # pins =  402 # available =  378
# time =  443 # pins =  403 # available =  379
# time =  444 # pins =  404 # available =  379
# time =  445 # pins =  405 # available =  380
# time =  446 # pins =  406 # available =  380
# time =  447 # pins =  407 # available =  381
# time =  449 # pins =  408 # available =  382
# time =  450 # pins =  409 # available =  383
# time =  451 # pins =  410 # available =  383
# time =  453 # pins =  411 # available =  384
# time =  454 # pins =  412 # available =  385
# time =  455 # pins =  413 # available =  386
# time =  456 # pins =  414 # available =  387
# time =  457 # pins =  415 # available =  387
# time =  458 # pins =  416 # available =  387
# time =  459 # pins =  417 # available =  388
# time =  460 # pins =  418 # available =  389
# time =  461 # pins =  419 # available =  390
# time =  462 # pins =  420 # available =  391
# time =  463 # pins =  421 # available =  392
# time =  464 # pins =  422 # available =  393
# time =  465 # pins =  423 # available =  394
# time =  466 # pins =  424 # available =  395
# time =  467 # pins =  425 # available =  396
# time =  468 # pins =  426 # available =  397
# time =  469 # pins =  427 # available =  398
# time =  470 # pins =  428 # available =  399
# time =  471 # pins =  429 # available =  399
# time =  472 # pins =  430 # available =  400
# time =  474 # pins =  431 # available =  401
# time =  475 # pins =  432 # available =  402
# time =  477 # pins =  433 # available =  403
# time =  478 # pins =  434 # available =  404
# time =  479 # pins =  435 # available =  405
# time =  480 # pins =  436 # available =  406
# time =  481 # pins =  437 # available =  406
# time =  482 # pins =  438 # available =  407
# time =  483 # pins =  439 # available =  408
# time =  484 # pins =  440 # available =  409
# time =  485 # pins =  441 # available =  410
# time =  487 # pins =  442 # available =  411
# time =  488 # pins =  443 # available =  411
# time =  490 # pins =  444 # available =  411
# time =  492 # pins =  445 # available =  412
# time =  493 # pins =  446 # available =  413
# time =  495 # pins =  447 # available =  412
# time =  496 # pins =  448 # available =  413
# time =  497 # pins =  449 # available =  413
# time =  498 # pins =  450 # available =  414
# time =  499 # pins =  451 # available =  415
# time =  500 # pins =  452 # available =  416
# time =  501 # pins =  453 # available =  417
# time =  502 # pins =  454 # available =  418
# time =  503 # pins =  455 # available =  419
# time =  504 # pins =  456 # available =  420
# time =  506 # pins =  457 # available =  421
# time =  507 # pins =  458 # available =  422
# time =  508 # pins =  459 # available =  423
# time =  511 # pins =  460 # available =  424
# time =  512 # pins =  461 # available =  425
# time =  514 # pins =  462 # available =  426
# time =  515 # pins =  463 # available =  427
# time =  516 # pins =  464 # available =  428
# time =  517 # pins =  465 # available =  429
# time =  518 # pins =  466 # available =  430
# time =  519 # pins =  467 # available =  431
# time =  520 # pins =  468 # available =  432
# time =  522 # pins =  469 # available =  433
# time =  523 # pins =  470 # available =  434
# time =  525 # pins =  471 # available =  435
# time =  527 # pins =  472 # available =  436
# time =  528 # pins =  473 # available =  436
# time =  530 # pins =  474 # available =  436
# time =  531 # pins =  475 # available =  437
# time =  532 # pins =  476 # available =  438
# time =  533 # pins =  477 # available =  438
# time =  534 # pins =  478 # available =  439
# time =  535 # pins =  479 # available =  440
# time =  537 # pins =  480 # available =  441
# time =  538 # pins =  481 # available =  442
# time =  539 # pins =  482 # available =  443
# time =  541 # pins =  483 # available =  444
# time =  542 # pins =  484 # available =  445
# time =  543 # pins =  485 # available =  446
# time =  544 # pins =  486 # available =  447
# time =  545 # pins =  487 # available =  448
# time =  546 # pins =  488 # available =  448
# time =  547 # pins =  489 # available =  449
# time =  549 # pins =  490 # available =  449
# time =  550 # pins =  491 # available =  450
# time =  551 # pins =  492 # available =  451
# time =  552 # pins =  493 # available =  452
# time =  553 # pins =  494 # available =  453
# time =  554 # pins =  495 # available =  452
# time =  555 # pins =  496 # available =  452
# time =  557 # pins =  497 # available =  452
# time =  558 # pins =  498 # available =  452
# time =  559 # pins =  499 # available =  452
# time =  560 # pins =  500 # available =  453
# time =  561 # pins =  501 # available =  454
# time =  562 # pins =  502 # available =  455
# time =  564 # pins =  503 # available =  455
# time =  565 # pins =  504 # available =  456
# time =  566 # pins =  505 # available =  457
# time =  567 # pins =  506 # available =  458
# time =  568 # pins =  507 # available =  458
# time =  569 # pins =  508 # available =  459
# time =  570 # pins =  509 # available =  460
# time =  572 # pins =  510 # available =  460
# time =  573 # pins =  511 # available =  461
# time =  574 # pins =  512 # available =  462
# time =  575 # pins =  513 # available =  463
# time =  576 # pins =  514 # available =  463
# time =  579 # pins =  515 # available =  463
# time =  580 # pins =  516 # available =  464
# time =  581 # pins =  517 # available =  464
# time =  582 # pins =  518 # available =  465
# time =  583 # pins =  519 # available =  466
# time =  584 # pins =  520 # available =  467
# time =  585 # pins =  521 # available =  468
# time =  586 # pins =  522 # available =  469
# time =  587 # pins =  523 # available =  470
# time =  588 # pins =  524 # available =  471
# time =  590 # pins =  525 # available =  472
# time =  593 # pins =  526 # available =  472
# time =  594 # pins =  527 # available =  473
# time =  595 # pins =  528 # available =  473
# time =  596 # pins =  529 # available =  474
# time =  597 # pins =  530 # available =  474
# time =  598 # pins =  531 # available =  474
# time =  600 # pins =  532 # available =  475
# time =  601 # pins =  533 # available =  476
# time =  602 # pins =  534 # available =  477
# time =  603 # pins =  535 # available =  477
# time =  604 # pins =  536 # available =  478
# time =  605 # pins =  537 # available =  478
# time =  606 # pins =  538 # available =  479
# time =  607 # pins =  539 # available =  480
# time =  609 # pins =  540 # available =  481
# time =  610 # pins =  541 # available =  482
# time =  611 # pins =  542 # available =  482
# time =  612 # pins =  543 # available =  483
# time =  613 # pins =  544 # available =  484
# time =  614 # pins =  545 # available =  485
# time =  615 # pins =  546 # available =  486
# time =  617 # pins =  547 # available =  487
# time =  620 # pins =  548 # available =  488
# time =  621 # pins =  549 # available =  489
# time =  622 # pins =  550 # available =  490
# time =  623 # pins =  551 # available =  491
# time =  624 # pins =  552 # available =  491
# time =  625 # pins =  553 # available =  492
# time =  626 # pins =  554 # available =  493
# time =  628 # pins =  555 # available =  494
# time =  629 # pins =  556 # available =  494
# time =  630 # pins =  557 # available =  495
# time =  632 # pins =  558 # available =  496
# time =  633 # pins =  559 # available =  497
# time =  634 # pins =  560 # available =  498
# time =  635 # pins =  561 # available =  499
# time =  636 # pins =  562 # available =  500
# time =  638 # pins =  563 # available =  501
# time =  639 # pins =  564 # available =  501
# time =  645 # pins =  565 # available =  502
# time =  646 # pins =  566 # available =  502
# time =  647 # pins =  567 # available =  503
# time =  648 # pins =  568 # available =  504
# time =  650 # pins =  569 # available =  505
# time =  652 # pins =  570 # available =  506
# time =  653 # pins =  571 # available =  507
# time =  654 # pins =  572 # available =  507
# time =  655 # pins =  573 # available =  508
# time =  656 # pins =  574 # available =  509
# time =  657 # pins =  575 # available =  509
# time =  658 # pins =  576 # available =  510
# time =  659 # pins =  577 # available =  511
# time =  660 # pins =  578 # available =  511
# time =  661 # pins =  579 # available =  512
# time =  662 # pins =  580 # available =  513
# time =  663 # pins =  581 # available =  513
# time =  664 # pins =  582 # available =  513
# time =  665 # pins =  583 # available =  514
# time =  667 # pins =  584 # available =  515
# time =  668 # pins =  585 # available =  516
# time =  671 # pins =  586 # available =  517
# time =  672 # pins =  587 # available =  518
# time =  674 # pins =  588 # available =  518
# time =  675 # pins =  589 # available =  519
# time =  676 # pins =  590 # available =  520
# time =  677 # pins =  591 # available =  521
# time =  678 # pins =  592 # available =  521
# time =  679 # pins =  593 # available =  522
# time =  680 # pins =  594 # available =  523
# time =  681 # pins =  595 # available =  524
# time =  682 # pins =  596 # available =  525
# time =  683 # pins =  597 # available =  526
# time =  684 # pins =  598 # available =  525
# time =  685 # pins =  599 # available =  526
# time =  688 # pins =  600 # available =  527
# time =  690 # pins =  601 # available =  528
# time =  692 # pins =  602 # available =  529
# time =  694 # pins =  603 # available =  530
# time =  696 # pins =  604 # available =  531
# time =  697 # pins =  605 # available =  532
# time =  698 # pins =  606 # available =  533
# time =  699 # pins =  607 # available =  534
# time =  700 # pins =  608 # available =  535
# time =  702 # pins =  609 # available =  536
# time =  703 # pins =  610 # available =  537
# time =  704 # pins =  611 # available =  538
# time =  705 # pins =  612 # available =  539
# time =  706 # pins =  613 # available =  540
# time =  707 # pins =  614 # available =  541
# time =  710 # pins =  615 # available =  542
# time =  711 # pins =  616 # available =  543
# time =  712 # pins =  617 # available =  544
# time =  714 # pins =  618 # available =  544
# time =  716 # pins =  619 # available =  545
# time =  717 # pins =  620 # available =  546
# time =  718 # pins =  621 # available =  547
# time =  721 # pins =  622 # available =  547
# time =  724 # pins =  623 # available =  548
# time =  726 # pins =  624 # available =  549
# time =  728 # pins =  625 # available =  550
# time =  729 # pins =  626 # available =  551
# time =  730 # pins =  627 # available =  552
# time =  731 # pins =  628 # available =  553
# time =  732 # pins =  629 # available =  554
# time =  733 # pins =  630 # available =  555
# time =  734 # pins =  631 # available =  556
# time =  736 # pins =  632 # available =  557
# time =  737 # pins =  633 # available =  558
# time =  738 # pins =  634 # available =  559
# time =  740 # pins =  635 # available =  560
# time =  741 # pins =  636 # available =  561
# time =  742 # pins =  637 # available =  562
# time =  744 # pins =  638 # available =  562
# time =  745 # pins =  639 # available =  563
# time =  746 # pins =  640 # available =  563
# time =  747 # pins =  641 # available =  563
# time =  748 # pins =  642 # available =  564
# time =  749 # pins =  643 # available =  565
# time =  754 # pins =  644 # available =  566
# time =  755 # pins =  645 # available =  566
# time =  756 # pins =  646 # available =  567
# time =  757 # pins =  647 # available =  568
# time =  758 # pins =  648 # available =  568
# time =  759 # pins =  649 # available =  569
# time =  763 # pins =  650 # available =  570
# time =  764 # pins =  651 # available =  571
# time =  765 # pins =  652 # available =  572
# time =  766 # pins =  653 # available =  573
# time =  767 # pins =  654 # available =  573
# time =  768 # pins =  655 # available =  573
# time =  771 # pins =  656 # available =  574
# time =  772 # pins =  657 # available =  575
# time =  773 # pins =  658 # available =  575
# time =  774 # pins =  659 # available =  576
# time =  775 # pins =  660 # available =  577
# time =  776 # pins =  661 # available =  578
# time =  777 # pins =  662 # available =  579
# time =  779 # pins =  663 # available =  579
# time =  780 # pins =  664 # available =  580
# time =  781 # pins =  665 # available =  581
# time =  782 # pins =  666 # available =  581
# time =  783 # pins =  667 # available =  582
# time =  784 # pins =  668 # available =  582
# time =  785 # pins =  669 # available =  582
# time =  786 # pins =  670 # available =  583
# time =  787 # pins =  671 # available =  583
# time =  789 # pins =  672 # available =  584
# time =  790 # pins =  673 # available =  585
# time =  792 # pins =  674 # available =  586
# time =  794 # pins =  675 # available =  587
# time =  795 # pins =  676 # available =  588
# time =  796 # pins =  677 # available =  588
# time =  797 # pins =  678 # available =  589
# time =  798 # pins =  679 # available =  590
# time =  799 # pins =  680 # available =  590
# time =  800 # pins =  681 # available =  591
# time =  801 # pins =  682 # available =  592
# time =  802 # pins =  683 # available =  593
# time =  804 # pins =  684 # available =  593
# time =  807 # pins =  685 # available =  594
# time =  808 # pins =  686 # available =  595
# time =  809 # pins =  687 # available =  596
# time =  810 # pins =  688 # available =  597
# time =  811 # pins =  689 # available =  598
# time =  812 # pins =  690 # available =  599
# time =  813 # pins =  691 # available =  600
# time =  814 # pins =  692 # available =  601
# time =  815 # pins =  693 # available =  602
# time =  817 # pins =  694 # available =  602
# time =  818 # pins =  695 # available =  603
# time =  821 # pins =  696 # available =  604
# time =  823 # pins =  697 # available =  604
# time =  824 # pins =  698 # available =  605
# time =  825 # pins =  699 # available =  606
# time =  827 # pins =  700 # available =  607
# time =  828 # pins =  701 # available =  608
# time =  829 # pins =  702 # available =  608
# time =  830 # pins =  703 # available =  609
# time =  831 # pins =  704 # available =  610
# time =  832 # pins =  705 # available =  611
# time =  833 # pins =  706 # available =  612
# time =  835 # pins =  707 # available =  613
# time =  836 # pins =  708 # available =  614
# time =  838 # pins =  709 # available =  615
# time =  839 # pins =  710 # available =  615
# time =  840 # pins =  711 # available =  616
# time =  841 # pins =  712 # available =  617
# time =  842 # pins =  713 # available =  618
# time =  843 # pins =  714 # available =  618
# time =  845 # pins =  715 # available =  618
# time =  846 # pins =  716 # available =  619
# time =  847 # pins =  717 # available =  620
# time =  848 # pins =  718 # available =  620
# time =  849 # pins =  719 # available =  621
# time =  852 # pins =  720 # available =  622
# time =  855 # pins =  721 # available =  623
# time =  856 # pins =  722 # available =  624
# time =  857 # pins =  723 # available =  625
# time =  861 # pins =  724 # available =  626
# time =  862 # pins =  725 # available =  627
# time =  864 # pins =  726 # available =  628
# time =  865 # pins =  727 # available =  628
# time =  867 # pins =  728 # available =  629
# time =  868 # pins =  729 # available =  630
# time =  869 # pins =  730 # available =  630
# time =  870 # pins =  731 # available =  631
# time =  874 # pins =  732 # available =  632
# time =  875 # pins =  733 # available =  633
# time =  876 # pins =  734 # available =  634
# time =  877 # pins =  735 # available =  635
# time =  878 # pins =  736 # available =  636
# time =  879 # pins =  737 # available =  637
# time =  880 # pins =  738 # available =  638
# time =  882 # pins =  739 # available =  639
# time =  883 # pins =  740 # available =  640
# time =  884 # pins =  741 # available =  641
# time =  886 # pins =  742 # available =  642
# time =  888 # pins =  743 # available =  643
# time =  891 # pins =  744 # available =  643
# time =  892 # pins =  745 # available =  644
# time =  894 # pins =  746 # available =  644
# time =  895 # pins =  747 # available =  645
# time =  896 # pins =  748 # available =  646
# time =  898 # pins =  749 # available =  646
# time =  901 # pins =  750 # available =  647
# time =  902 # pins =  751 # available =  648
# time =  903 # pins =  752 # available =  648
# time =  905 # pins =  753 # available =  649
# time =  906 # pins =  754 # available =  650
# time =  908 # pins =  755 # available =  651
# time =  909 # pins =  756 # available =  652
# time =  910 # pins =  757 # available =  653
# time =  911 # pins =  758 # available =  654
# time =  912 # pins =  759 # available =  655
# time =  915 # pins =  760 # available =  655
# time =  916 # pins =  761 # available =  656
# time =  917 # pins =  762 # available =  656
# time =  918 # pins =  763 # available =  657
# time =  919 # pins =  764 # available =  657
# time =  920 # pins =  765 # available =  657
# time =  921 # pins =  766 # available =  658
# time =  924 # pins =  767 # available =  657
# time =  925 # pins =  768 # available =  658
# time =  926 # pins =  769 # available =  659
# time =  929 # pins =  770 # available =  660
# time =  931 # pins =  771 # available =  661
# time =  932 # pins =  772 # available =  662
# time =  933 # pins =  773 # available =  662
# time =  935 # pins =  774 # available =  662
# time =  936 # pins =  775 # available =  663
# time =  937 # pins =  776 # available =  664
# time =  938 # pins =  777 # available =  665
# time =  940 # pins =  778 # available =  665
# time =  941 # pins =  779 # available =  666
# time =  942 # pins =  780 # available =  666
# time =  943 # pins =  781 # available =  665
# time =  944 # pins =  782 # available =  665
# time =  945 # pins =  783 # available =  666
# time =  946 # pins =  784 # available =  667
# time =  947 # pins =  785 # available =  668
# time =  948 # pins =  786 # available =  669
# time =  949 # pins =  787 # available =  669
# time =  950 # pins =  788 # available =  670
# time =  951 # pins =  789 # available =  671
# time =  952 # pins =  790 # available =  672
# time =  953 # pins =  791 # available =  672
# time =  954 # pins =  792 # available =  673
# time =  955 # pins =  793 # available =  674
# time =  956 # pins =  794 # available =  675
# time =  957 # pins =  795 # available =  676
# time =  958 # pins =  796 # available =  676
# time =  961 # pins =  797 # available =  677
# time =  964 # pins =  798 # available =  678
# time =  966 # pins =  799 # available =  679
# time =  967 # pins =  800 # available =  678
# time =  968 # pins =  801 # available =  679
# time =  969 # pins =  802 # available =  680
# time =  970 # pins =  803 # available =  681
# time =  973 # pins =  804 # available =  682
# time =  977 # pins =  805 # available =  683
# time =  979 # pins =  806 # available =  684
# time =  980 # pins =  807 # available =  684
# time =  981 # pins =  808 # available =  685
# time =  982 # pins =  809 # available =  686
# time =  984 # pins =  810 # available =  687
# time =  985 # pins =  811 # available =  688
# time =  986 # pins =  812 # available =  688
# time =  989 # pins =  813 # available =  687
# time =  990 # pins =  814 # available =  687
# time =  991 # pins =  815 # available =  688
# time =  992 # pins =  816 # available =  689
# time =  993 # pins =  817 # available =  688
# time =  994 # pins =  818 # available =  689
# time =  995 # pins =  819 # available =  690
# time =  996 # pins =  820 # available =  691
# time =  997 # pins =  821 # available =  692
# time =  999 # pins =  822 # available =  692
# time =  1000 # pins =  823 # available =  693
# time =  1001 # pins =  824 # available =  693
# time =  1002 # pins =  825 # available =  694
# time =  1003 # pins =  826 # available =  694
# time =  1004 # pins =  827 # available =  695
# time =  1006 # pins =  828 # available =  696
# time =  1008 # pins =  829 # available =  697
# time =  1009 # pins =  830 # available =  697
# time =  1012 # pins =  831 # available =  697
# time =  1013 # pins =  832 # available =  698
# time =  1014 # pins =  833 # available =  699
# time =  1015 # pins =  834 # available =  699
# time =  1016 # pins =  835 # available =  700
# time =  1017 # pins =  836 # available =  701
# time =  1018 # pins =  837 # available =  700
# time =  1020 # pins =  838 # available =  701
# time =  1021 # pins =  839 # available =  701
# time =  1022 # pins =  840 # available =  700
# time =  1023 # pins =  841 # available =  700
# time =  1025 # pins =  842 # available =  700
# time =  1026 # pins =  843 # available =  700
# time =  1027 # pins =  844 # available =  701
# time =  1028 # pins =  845 # available =  702
# time =  1029 # pins =  846 # available =  703
# time =  1030 # pins =  847 # available =  703
# time =  1032 # pins =  848 # available =  703
# time =  1035 # pins =  849 # available =  704
# time =  1038 # pins =  850 # available =  705
# time =  1040 # pins =  851 # available =  706
# time =  1043 # pins =  852 # available =  707
# time =  1044 # pins =  853 # available =  707
# time =  1045 # pins =  854 # available =  708
# time =  1046 # pins =  855 # available =  709
# time =  1049 # pins =  856 # available =  709
# time =  1052 # pins =  857 # available =  709
# time =  1053 # pins =  858 # available =  710
# time =  1054 # pins =  859 # available =  711
# time =  1055 # pins =  860 # available =  711
# time =  1056 # pins =  861 # available =  712
# time =  1057 # pins =  862 # available =  712
# time =  1058 # pins =  863 # available =  713
# time =  1059 # pins =  864 # available =  713
# time =  1060 # pins =  865 # available =  714
# time =  1062 # pins =  866 # available =  715
# time =  1063 # pins =  867 # available =  716
# time =  1064 # pins =  868 # available =  717
# time =  1065 # pins =  869 # available =  717
# time =  1068 # pins =  870 # available =  718
# time =  1069 # pins =  871 # available =  719
# time =  1070 # pins =  872 # available =  720
# time =  1071 # pins =  873 # available =  721
# time =  1072 # pins =  874 # available =  721
# time =  1073 # pins =  875 # available =  722
# time =  1074 # pins =  876 # available =  723
# time =  1076 # pins =  877 # available =  724
# time =  1077 # pins =  878 # available =  725
# time =  1078 # pins =  879 # available =  726
# time =  1079 # pins =  880 # available =  727
# time =  1080 # pins =  881 # available =  728
# time =  1082 # pins =  882 # available =  729
# time =  1083 # pins =  883 # available =  730
# time =  1084 # pins =  884 # available =  730
# time =  1085 # pins =  885 # available =  731
# time =  1086 # pins =  886 # available =  731
# time =  1087 # pins =  887 # available =  731
# time =  1088 # pins =  888 # available =  732
# time =  1091 # pins =  889 # available =  733
# time =  1092 # pins =  890 # available =  733
# time =  1095 # pins =  891 # available =  734
# time =  1096 # pins =  892 # available =  734
# time =  1098 # pins =  893 # available =  734
# time =  1099 # pins =  894 # available =  735
# time =  1100 # pins =  895 # available =  736
# time =  1101 # pins =  896 # available =  737
# time =  1102 # pins =  897 # available =  738
# time =  1103 # pins =  898 # available =  739
# time =  1105 # pins =  899 # available =  740
# time =  1108 # pins =  900 # available =  741
# time =  1109 # pins =  901 # available =  742
# time =  1111 # pins =  902 # available =  741
# time =  1114 # pins =  903 # available =  741
# time =  1116 # pins =  904 # available =  742
# time =  1117 # pins =  905 # available =  743
# time =  1118 # pins =  906 # available =  744
# time =  1120 # pins =  907 # available =  745
# time =  1121 # pins =  908 # available =  745
# time =  1122 # pins =  909 # available =  746
# time =  1124 # pins =  910 # available =  747
# time =  1127 # pins =  911 # available =  748
# time =  1128 # pins =  912 # available =  749
# time =  1129 # pins =  913 # available =  750
# time =  1130 # pins =  914 # available =  751
# time =  1132 # pins =  915 # available =  751
# time =  1133 # pins =  916 # available =  752
# time =  1135 # pins =  917 # available =  753
# time =  1137 # pins =  918 # available =  754
# time =  1138 # pins =  919 # available =  755
# time =  1139 # pins =  920 # available =  756
# time =  1142 # pins =  921 # available =  756
# time =  1144 # pins =  922 # available =  756
# time =  1145 # pins =  923 # available =  756
# time =  1146 # pins =  924 # available =  756
# time =  1148 # pins =  925 # available =  757
# time =  1150 # pins =  926 # available =  758
# time =  1151 # pins =  927 # available =  759
# time =  1152 # pins =  928 # available =  760
# time =  1153 # pins =  929 # available =  761
# time =  1154 # pins =  930 # available =  762
# time =  1155 # pins =  931 # available =  763
# time =  1156 # pins =  932 # available =  763
# time =  1157 # pins =  933 # available =  763
# time =  1162 # pins =  934 # available =  763
# time =  1163 # pins =  935 # available =  764
# time =  1166 # pins =  936 # available =  764
# time =  1167 # pins =  937 # available =  765
# time =  1169 # pins =  938 # available =  766
# time =  1171 # pins =  939 # available =  767
# time =  1173 # pins =  940 # available =  768
# time =  1175 # pins =  941 # available =  769
# time =  1176 # pins =  942 # available =  768
# time =  1177 # pins =  943 # available =  768
# time =  1179 # pins =  944 # available =  769
# time =  1181 # pins =  945 # available =  769
# time =  1182 # pins =  946 # available =  769
# time =  1183 # pins =  947 # available =  770
# time =  1186 # pins =  948 # available =  771
# time =  1188 # pins =  949 # available =  772
# time =  1190 # pins =  950 # available =  772
# time =  1192 # pins =  951 # available =  772
# time =  1194 # pins =  952 # available =  772
# time =  1195 # pins =  953 # available =  772
# time =  1199 # pins =  954 # available =  773
# time =  1201 # pins =  955 # available =  774
# time =  1202 # pins =  956 # available =  774
# time =  1204 # pins =  957 # available =  774
# time =  1205 # pins =  958 # available =  774
# time =  1207 # pins =  959 # available =  774
# time =  1208 # pins =  960 # available =  775
# time =  1209 # pins =  961 # available =  776
# time =  1210 # pins =  962 # available =  777
# time =  1211 # pins =  963 # available =  778
# time =  1212 # pins =  964 # available =  779
# time =  1213 # pins =  965 # available =  780
# time =  1214 # pins =  966 # available =  781
# time =  1215 # pins =  967 # available =  781
# time =  1216 # pins =  968 # available =  782
# time =  1217 # pins =  969 # available =  782
# time =  1218 # pins =  970 # available =  783
# time =  1220 # pins =  971 # available =  784
# time =  1221 # pins =  972 # available =  785
# time =  1223 # pins =  973 # available =  785
# time =  1224 # pins =  974 # available =  786
# time =  1226 # pins =  975 # available =  787
# time =  1231 # pins =  976 # available =  788
# time =  1232 # pins =  977 # available =  789
# time =  1233 # pins =  978 # available =  789
# time =  1234 # pins =  979 # available =  790
# time =  1235 # pins =  980 # available =  791
# time =  1237 # pins =  981 # available =  791
# time =  1239 # pins =  982 # available =  791
# time =  1241 # pins =  983 # available =  791
# time =  1243 # pins =  984 # available =  792
# time =  1245 # pins =  985 # available =  793
# time =  1246 # pins =  986 # available =  794
# time =  1247 # pins =  987 # available =  794
# time =  1248 # pins =  988 # available =  794
# time =  1249 # pins =  989 # available =  794
# time =  1250 # pins =  990 # available =  794
# time =  1252 # pins =  991 # available =  795
# time =  1253 # pins =  992 # available =  796
# time =  1254 # pins =  993 # available =  797
# time =  1255 # pins =  994 # available =  798
# time =  1256 # pins =  995 # available =  799
# time =  1258 # pins =  996 # available =  800
# time =  1261 # pins =  997 # available =  801
# time =  1262 # pins =  998 # available =  801
# time =  1263 # pins =  999 # available =  802
# time =  1264 # pins =  1000 # available =  803
# time =  1266 # pins =  1001 # available =  803
# time =  1268 # pins =  1002 # available =  803
# time =  1272 # pins =  1003 # available =  804
# time =  1273 # pins =  1004 # available =  804
# time =  1274 # pins =  1005 # available =  804
# time =  1275 # pins =  1006 # available =  805
# time =  1277 # pins =  1007 # available =  805
# time =  1279 # pins =  1008 # available =  806
# time =  1280 # pins =  1009 # available =  807
# time =  1281 # pins =  1010 # available =  807
# time =  1282 # pins =  1011 # available =  808
# time =  1283 # pins =  1012 # available =  809
# time =  1284 # pins =  1013 # available =  810
# time =  1285 # pins =  1014 # available =  811
# time =  1286 # pins =  1015 # available =  812
# time =  1287 # pins =  1016 # available =  813
# time =  1288 # pins =  1017 # available =  814
# time =  1289 # pins =  1018 # available =  814
# time =  1291 # pins =  1019 # available =  814
# time =  1292 # pins =  1020 # available =  814
# time =  1293 # pins =  1021 # available =  815
# time =  1294 # pins =  1022 # available =  816
# time =  1296 # pins =  1023 # available =  817
# time =  1297 # pins =  1024 # available =  818
# time =  1298 # pins =  1025 # available =  818
# time =  1299 # pins =  1026 # available =  818
# time =  1302 # pins =  1027 # available =  819
# time =  1304 # pins =  1028 # available =  820
# time =  1305 # pins =  1029 # available =  820
# time =  1306 # pins =  1030 # available =  821
# time =  1307 # pins =  1031 # available =  822
# time =  1308 # pins =  1032 # available =  822
# time =  1309 # pins =  1033 # available =  823
# time =  1312 # pins =  1034 # available =  824
# time =  1313 # pins =  1035 # available =  824
# time =  1314 # pins =  1036 # available =  825
# time =  1315 # pins =  1037 # available =  824
# time =  1318 # pins =  1038 # available =  825
# time =  1319 # pins =  1039 # available =  825
# time =  1321 # pins =  1040 # available =  826
# time =  1322 # pins =  1041 # available =  827
# time =  1323 # pins =  1042 # available =  828
# time =  1324 # pins =  1043 # available =  829
# time =  1325 # pins =  1044 # available =  830
# time =  1326 # pins =  1045 # available =  831
# time =  1327 # pins =  1046 # available =  831
# time =  1328 # pins =  1047 # available =  832
# time =  1330 # pins =  1048 # available =  833
# time =  1331 # pins =  1049 # available =  832
# time =  1332 # pins =  1050 # available =  833
# time =  1333 # pins =  1051 # available =  834
# time =  1336 # pins =  1052 # available =  835
# time =  1341 # pins =  1053 # available =  836
# time =  1342 # pins =  1054 # available =  837
# time =  1343 # pins =  1055 # available =  838
# time =  1348 # pins =  1056 # available =  839
# time =  1349 # pins =  1057 # available =  840
# time =  1350 # pins =  1058 # available =  840
# time =  1351 # pins =  1059 # available =  840
# time =  1353 # pins =  1060 # available =  840
# time =  1354 # pins =  1061 # available =  839
# time =  1356 # pins =  1062 # available =  840
# time =  1358 # pins =  1063 # available =  841
# time =  1360 # pins =  1064 # available =  842
# time =  1361 # pins =  1065 # available =  843
# time =  1362 # pins =  1066 # available =  842
# ...
# time =  22754 # pins =  3407 # available =  332
# time =  22951 # pins =  3408 # available =  331
# time =  23120 # pins =  3409 # available =  330
# time =  23198 # pins =  3410 # available =  329
# time =  23208 # pins =  3411 # available =  328
# time =  23212 # pins =  3412 # available =  327
# time =  23234 # pins =  3413 # available =  326
# time =  23433 # pins =  3414 # available =  325
# time =  23508 # pins =  3415 # available =  324
# time =  23757 # pins =  3416 # available =  323
# time =  23867 # pins =  3417 # available =  322
# time =  23884 # pins =  3418 # available =  321
# time =  23991 # pins =  3419 # available =  320
# time =  24271 # pins =  3420 # available =  319
# time =  24284 # pins =  3421 # available =  318
# time =  24304 # pins =  3422 # available =  317
# time =  24359 # pins =  3423 # available =  316
# time =  24470 # pins =  3424 # available =  315
# time =  24569 # pins =  3425 # available =  314
# time =  24637 # pins =  3426 # available =  313
# time =  24652 # pins =  3427 # available =  312
# time =  24851 # pins =  3428 # available =  311
# time =  24867 # pins =  3429 # available =  310
# time =  25178 # pins =  3430 # available =  309
# time =  25229 # pins =  3431 # available =  308
# time =  25523 # pins =  3432 # available =  307
# time =  25567 # pins =  3433 # available =  306
# time =  25811 # pins =  3434 # available =  305
# time =  25834 # pins =  3435 # available =  304
# time =  25872 # pins =  3436 # available =  303
# time =  26003 # pins =  3437 # available =  302
# time =  26014 # pins =  3438 # available =  301
# time =  26148 # pins =  3439 # available =  300
# time =  26329 # pins =  3440 # available =  299
# time =  26334 # pins =  3441 # available =  298
# time =  26508 # pins =  3442 # available =  297
# time =  26579 # pins =  3443 # available =  296
# time =  26639 # pins =  3444 # available =  295
# time =  26766 # pins =  3445 # available =  294
# time =  26917 # pins =  3446 # available =  293
# time =  27021 # pins =  3447 # available =  292
# time =  27049 # pins =  3448 # available =  291
# time =  27085 # pins =  3449 # available =  290
# time =  27137 # pins =  3450 # available =  289
# time =  27231 # pins =  3451 # available =  288
# time =  27248 # pins =  3452 # available =  287
# time =  27305 # pins =  3453 # available =  286
# time =  27413 # pins =  3454 # available =  285
# time =  27452 # pins =  3455 # available =  284
# time =  27471 # pins =  3456 # available =  283
# time =  27498 # pins =  3457 # available =  282
# time =  27596 # pins =  3458 # available =  281
# time =  27622 # pins =  3459 # available =  280
# time =  27658 # pins =  3460 # available =  279
# time =  27813 # pins =  3461 # available =  278
# time =  27834 # pins =  3462 # available =  277
# time =  27880 # pins =  3463 # available =  276
# time =  28369 # pins =  3464 # available =  275
# time =  28490 # pins =  3465 # available =  274
# time =  28492 # pins =  3466 # available =  273
# time =  28565 # pins =  3467 # available =  272
# time =  28750 # pins =  3468 # available =  271
# time =  28907 # pins =  3469 # available =  270
# time =  28915 # pins =  3470 # available =  269
# time =  29242 # pins =  3471 # available =  268
# time =  29363 # pins =  3472 # available =  267
# time =  29385 # pins =  3473 # available =  266
# time =  29552 # pins =  3474 # available =  265
# time =  29832 # pins =  3475 # available =  264
# time =  30098 # pins =  3476 # available =  263
# time =  30169 # pins =  3477 # available =  262
# time =  30318 # pins =  3478 # available =  261
# time =  30338 # pins =  3479 # available =  260
# time =  30360 # pins =  3480 # available =  259
# time =  30363 # pins =  3481 # available =  258
# time =  30372 # pins =  3482 # available =  257
# time =  30401 # pins =  3483 # available =  256
# time =  30501 # pins =  3484 # available =  255
# time =  30528 # pins =  3485 # available =  254
# time =  30781 # pins =  3486 # available =  253
# time =  31111 # pins =  3487 # available =  252
# time =  31327 # pins =  3488 # available =  251
# time =  31451 # pins =  3489 # available =  250
# time =  31567 # pins =  3490 # available =  249
# time =  31620 # pins =  3491 # available =  248
# time =  31931 # pins =  3492 # available =  247
# time =  31948 # pins =  3493 # available =  246
# time =  31954 # pins =  3494 # available =  245
# time =  32315 # pins =  3495 # available =  244
# time =  32567 # pins =  3496 # available =  243
# time =  32752 # pins =  3497 # available =  242
# time =  32853 # pins =  3498 # available =  241
# time =  32918 # pins =  3499 # available =  240
# time =  33052 # pins =  3500 # available =  239
# time =  33155 # pins =  3501 # available =  238
# time =  33319 # pins =  3502 # available =  237
# time =  33610 # pins =  3503 # available =  236
# time =  33817 # pins =  3504 # available =  235
# time =  33837 # pins =  3505 # available =  234
# time =  33886 # pins =  3506 # available =  233
# time =  34226 # pins =  3507 # available =  232
# time =  34269 # pins =  3508 # available =  231
# time =  34367 # pins =  3509 # available =  230
# time =  34387 # pins =  3510 # available =  229
# time =  34446 # pins =  3511 # available =  228
# time =  34539 # pins =  3512 # available =  227
# time =  34718 # pins =  3513 # available =  226
# time =  34775 # pins =  3514 # available =  225
# time =  34810 # pins =  3515 # available =  224
# time =  34955 # pins =  3516 # available =  223
# time =  35034 # pins =  3517 # available =  222
# time =  35159 # pins =  3518 # available =  221
# time =  35368 # pins =  3519 # available =  220
# time =  35494 # pins =  3520 # available =  219
# time =  35627 # pins =  3521 # available =  218
# time =  35631 # pins =  3522 # available =  217
# time =  35769 # pins =  3523 # available =  216
# time =  35784 # pins =  3524 # available =  215
# time =  35797 # pins =  3525 # available =  214
# time =  36355 # pins =  3526 # available =  213
# time =  36379 # pins =  3527 # available =  212
# time =  37038 # pins =  3528 # available =  211
# time =  37571 # pins =  3529 # available =  210
# time =  37621 # pins =  3530 # available =  209
# time =  37792 # pins =  3531 # available =  208
# time =  37814 # pins =  3532 # available =  207
# time =  38064 # pins =  3533 # available =  206
# time =  38093 # pins =  3534 # available =  205
# time =  38129 # pins =  3535 # available =  204
# time =  38138 # pins =  3536 # available =  203
# time =  38308 # pins =  3537 # available =  202
# time =  38312 # pins =  3538 # available =  201
# time =  38819 # pins =  3539 # available =  200
# time =  38926 # pins =  3540 # available =  199
# time =  39086 # pins =  3541 # available =  198
# time =  39232 # pins =  3542 # available =  197
# time =  39298 # pins =  3543 # available =  196
# time =  39668 # pins =  3544 # available =  195
# time =  40073 # pins =  3545 # available =  194
# time =  40148 # pins =  3546 # available =  193
# time =  40153 # pins =  3547 # available =  192
# time =  40664 # pins =  3548 # available =  191
# time =  40665 # pins =  3549 # available =  190
# time =  41441 # pins =  3550 # available =  189
# time =  41520 # pins =  3551 # available =  188
# time =  41545 # pins =  3552 # available =  187
# time =  41959 # pins =  3553 # available =  186
# time =  42108 # pins =  3554 # available =  185
# time =  42401 # pins =  3555 # available =  184
# time =  42425 # pins =  3556 # available =  183
# time =  42924 # pins =  3557 # available =  182
# time =  43290 # pins =  3558 # available =  181
# time =  43494 # pins =  3559 # available =  180
# time =  43528 # pins =  3560 # available =  179
# time =  43538 # pins =  3561 # available =  178
# time =  43547 # pins =  3562 # available =  177
# time =  43574 # pins =  3563 # available =  176
# time =  43701 # pins =  3564 # available =  175
# time =  43888 # pins =  3565 # available =  174
# time =  44093 # pins =  3566 # available =  173
# time =  44275 # pins =  3567 # available =  172
# time =  44473 # pins =  3568 # available =  171
# time =  44608 # pins =  3569 # available =  170
# time =  45254 # pins =  3570 # available =  169
# time =  45533 # pins =  3571 # available =  168
# time =  45793 # pins =  3572 # available =  167
# time =  46020 # pins =  3573 # available =  166
# time =  46067 # pins =  3574 # available =  165
# time =  46395 # pins =  3575 # available =  164
# time =  46503 # pins =  3576 # available =  163
# time =  46702 # pins =  3577 # available =  162
# time =  47025 # pins =  3578 # available =  161
# time =  47206 # pins =  3579 # available =  160
# time =  47518 # pins =  3580 # available =  159
# time =  47668 # pins =  3581 # available =  158
# time =  48143 # pins =  3582 # available =  157
# time =  48922 # pins =  3583 # available =  156
# time =  49025 # pins =  3584 # available =  155
# time =  49266 # pins =  3585 # available =  154
# time =  49655 # pins =  3586 # available =  153
# time =  49891 # pins =  3587 # available =  152
# time =  49988 # pins =  3588 # available =  151
# time =  50066 # pins =  3589 # available =  150
# time =  50083 # pins =  3590 # available =  149
# time =  50203 # pins =  3591 # available =  148
# time =  50373 # pins =  3592 # available =  147
# time =  50741 # pins =  3593 # available =  146
# time =  50905 # pins =  3594 # available =  145
# time =  51278 # pins =  3595 # available =  144
# time =  51339 # pins =  3596 # available =  143
# time =  51574 # pins =  3597 # available =  142
# time =  51726 # pins =  3598 # available =  141
# time =  52242 # pins =  3599 # available =  140
# time =  52394 # pins =  3600 # available =  139
# time =  52532 # pins =  3601 # available =  138
# time =  53480 # pins =  3602 # available =  137
# time =  53556 # pins =  3603 # available =  136
# time =  53634 # pins =  3604 # available =  135
# time =  53968 # pins =  3605 # available =  134
# time =  54181 # pins =  3606 # available =  133
# time =  55298 # pins =  3607 # available =  132
# time =  55627 # pins =  3608 # available =  131
# time =  55721 # pins =  3609 # available =  130
# time =  55733 # pins =  3610 # available =  129
# time =  56074 # pins =  3611 # available =  128
# time =  56249 # pins =  3612 # available =  127
# time =  56342 # pins =  3613 # available =  126
# time =  57821 # pins =  3614 # available =  125
# time =  58323 # pins =  3615 # available =  124
# time =  58986 # pins =  3616 # available =  123
# time =  60854 # pins =  3617 # available =  122
# time =  61145 # pins =  3618 # available =  121
# time =  61365 # pins =  3619 # available =  120
# time =  62354 # pins =  3620 # available =  119
# time =  62553 # pins =  3621 # available =  118
# time =  63600 # pins =  3622 # available =  117
# time =  63608 # pins =  3623 # available =  116
# time =  63676 # pins =  3624 # available =  115
# time =  65688 # pins =  3625 # available =  114
# time =  67760 # pins =  3626 # available =  113
# time =  68605 # pins =  3627 # available =  112
# time =  69041 # pins =  3628 # available =  111
# time =  69548 # pins =  3629 # available =  110
# time =  70298 # pins =  3630 # available =  109
# time =  70319 # pins =  3631 # available =  108
# time =  74173 # pins =  3632 # available =  107
# time =  74260 # pins =  3633 # available =  106
# time =  74647 # pins =  3634 # available =  105
# time =  74714 # pins =  3635 # available =  104
# time =  76346 # pins =  3636 # available =  103
# time =  76907 # pins =  3637 # available =  102
# time =  78015 # pins =  3638 # available =  101
# time =  79094 # pins =  3639 # available =  100
# time =  80024 # pins =  3640 # available =  99
# time =  81069 # pins =  3641 # available =  98
# time =  82859 # pins =  3642 # available =  97
# time =  83357 # pins =  3643 # available =  96
# time =  85550 # pins =  3644 # available =  95
# time =  85617 # pins =  3645 # available =  94
# time =  86250 # pins =  3646 # available =  93
# time =  88653 # pins =  3647 # available =  92
# time =  89351 # pins =  3648 # available =  91
# time =  90572 # pins =  3649 # available =  90
# time =  92072 # pins =  3650 # available =  89
# time =  92207 # pins =  3651 # available =  88
# time =  92226 # pins =  3652 # available =  87
# time =  94136 # pins =  3653 # available =  86
# time =  94237 # pins =  3654 # available =  85
# time =  95108 # pins =  3655 # available =  84
# time =  95145 # pins =  3656 # available =  83
# time =  102437 # pins =  3657 # available =  82
# time =  103790 # pins =  3658 # available =  81
# time =  104322 # pins =  3659 # available =  80
# time =  106249 # pins =  3660 # available =  79
# time =  107453 # pins =  3661 # available =  78
# time =  108528 # pins =  3662 # available =  77
# time =  108876 # pins =  3663 # available =  76
# time =  111972 # pins =  3664 # available =  75
# time =  114508 # pins =  3665 # available =  74
# time =  115572 # pins =  3666 # available =  73
# time =  115867 # pins =  3667 # available =  72
# time =  116891 # pins =  3668 # available =  71
# time =  117091 # pins =  3669 # available =  70
# time =  118789 # pins =  3670 # available =  69
# time =  119239 # pins =  3671 # available =  68
# time =  120770 # pins =  3672 # available =  67
# time =  121130 # pins =  3673 # available =  66
# time =  122226 # pins =  3674 # available =  65
# time =  125456 # pins =  3675 # available =  64
# time =  125804 # pins =  3676 # available =  63
# time =  125921 # pins =  3677 # available =  62
# time =  134903 # pins =  3678 # available =  61
# time =  135101 # pins =  3679 # available =  60
# time =  136165 # pins =  3680 # available =  59
# time =  138521 # pins =  3681 # available =  58
# time =  139920 # pins =  3682 # available =  57
# time =  140408 # pins =  3683 # available =  56
# time =  142408 # pins =  3684 # available =  55
# time =  142874 # pins =  3685 # available =  54
# time =  151430 # pins =  3686 # available =  53
# time =  152278 # pins =  3687 # available =  52
# time =  158645 # pins =  3688 # available =  51
# time =  158647 # pins =  3689 # available =  50
# time =  159405 # pins =  3690 # available =  49
# time =  160254 # pins =  3691 # available =  48
# time =  160640 # pins =  3692 # available =  47
# time =  163560 # pins =  3693 # available =  46
# time =  170259 # pins =  3694 # available =  45
# time =  173307 # pins =  3695 # available =  44
# time =  177828 # pins =  3696 # available =  43
# time =  178109 # pins =  3697 # available =  42
# time =  187978 # pins =  3698 # available =  41
# time =  190249 # pins =  3699 # available =  40
# time =  192961 # pins =  3700 # available =  39
# time =  197191 # pins =  3701 # available =  38
# time =  200154 # pins =  3702 # available =  37
# time =  207155 # pins =  3703 # available =  36
# time =  211582 # pins =  3704 # available =  35
# time =  211665 # pins =  3705 # available =  34
# time =  213727 # pins =  3706 # available =  33
# time =  218230 # pins =  3707 # available =  32
# time =  219623 # pins =  3708 # available =  31
# time =  219806 # pins =  3709 # available =  30
# time =  225741 # pins =  3710 # available =  29
# time =  229035 # pins =  3711 # available =  28
# time =  254450 # pins =  3712 # available =  27
# time =  265887 # pins =  3713 # available =  26
# time =  293044 # pins =  3714 # available =  25
# time =  308652 # pins =  3715 # available =  24
# time =  313365 # pins =  3716 # available =  23
# time =  316002 # pins =  3717 # available =  22
# time =  324665 # pins =  3718 # available =  21
# time =  325229 # pins =  3719 # available =  20
# time =  384462 # pins =  3720 # available =  19
# time =  410783 # pins =  3721 # available =  18
# time =  435721 # pins =  3722 # available =  17
# time =  451557 # pins =  3723 # available =  16
# time =  485266 # pins =  3724 # available =  15
# time =  512062 # pins =  3725 # available =  14
# time =  541858 # pins =  3726 # available =  13
# time =  553265 # pins =  3727 # available =  12
# time =  575195 # pins =  3728 # available =  11
# time =  613758 # pins =  3729 # available =  10
# time =  682105 # pins =  3730 # available =  9
# time =  1026456 # pins =  3731 # available =  8
# time =  1043868 # pins =  3732 # available =  7
# time =  1072622 # pins =  3733 # available =  6
# time =  1438091 # pins =  3734 # available =  5
# time =  1931850 # pins =  3735 # available =  4
# time =  3667609 # pins =  3736 # available =  3
# time =  3899679 # pins =  3737 # available =  2
# time =  4168437 # pins =  3738 # available =  1
# time =  7905412 # pins =  3739 # available =  0
# Density =  0.7478

# %% [markdown]
# ## Faster than the clock algorithm
#
# As you must have seen, the real-time implementation of the algorithm can become very slow. Indeed,
# the probability to place the pins at the right places when there is not so much space left becomes
# very small. As a result, the simulation times can become very long. We will now see how this can
# be avoided by implementing a faster than the clock algorithm. Here are the steps:
#
# - Given a certain configuration of pins, make a list of all the intervals where new pins can
#   be inserted.
#
# - From the cumulative length of all these intervals, you can easily deduce the probability that the
#   next trial insertion will be accepted. You then also know the probability $p_r$ that this trial
#   will be rejected.
#
# - The distribution of the number of steps $t$ until a proposal is accepted is given by
#
#   $$
#   \pi(t) = p_r^{t-1} (1 - p_r)
#   $$
#
#   This distribution can be sampled from a uniform random variable $\xi \in [0,1]$ with
#
#   $$
#   t = 1 + \left\lfloor \frac{\log(\xi)}{\log(p_r)} \right\rfloor
#   $$
#
#   With the knowledge of $p_r$ you can generate a faster than the clock time until the next
#   accepted proposal.
#
# - Produce a new configuration of pins by randomly choosing a valid position for the new pin.
#   Be careful to pick this position uniformly across all valid intervals that you have found above.
#
# - Keep track of the times when pins were inserted.
#
# Hint: It is a good idea to construct the list of intervals by specifying both their length and the position on the line where they start. This will be useful to more easily find the place where the next pin will be inserted.

# %%
def compute_intervals(pins, sigma):
    """Given a configuration of pins, compute a list of all intervals where a further pin
       can be inserted. Returns both the length and the start of these intervals."""
    
    n_pins = len(pins)
    pin_array = np.array(pins)
    intervals = pin_array[1:n_pins] - pin_array[0:n_pins-1] - 4 * sigma
    starts = pin_array[0:n_pins-1] + 2 * sigma
    viable = intervals > 0
    
    return intervals[viable], starts[viable]

# %%
# parameters
sigma = 1
L = 10000

# initialize variables
pins = [-sigma, L+sigma]
times = [0]
rho = [0]
time = 0

# there is still some free interval
while(True):
    
    # compute intervals - stop if no interval left
    interval_length, interval_start = compute_intervals(pins, sigma)
    if not np.any(interval_length): break

    # cumulative length of allowed positions
    tot_length = np.sum(interval_length)
    
    # rejection probability
    p_reject = 1 - tot_length / (L - 2*sigma)
    
    # find next allowed position
    r = np.random.uniform(0, tot_length)
    cum_length = np.cumsum(interval_length)
    ind = bisect.bisect(cum_length, r)
    delta = r - cum_length[ind-1] if ind > 0 else r
    position = interval_start[ind] + delta

    # insert pin
    bisect.insort(pins, position)
    
    # compute faster than the clock time
    time += 1
    if p_reject > 0:
        time += int(np.log(np.random.rand()) / np.log(p_reject))
        
    # store times and densities
    times.append(time)
    rho.append((len(pins)-2) * 2 * sigma / L)
        
print("Density = ", (len(pins)-2) * 2 * sigma / L)

# %% [markdown]
# ## Comparison with analytical solution
#
# It can be shown that the distribution of the density of pins as a function of
# time is given by
#
# $$
# \rho(T) = \int_0^T  du\;\exp\left\{-2\int_{0}^u\frac{dv}{v}(1-e^{-v})\right\}
# $$
#
# where $T = 2\sigma t/L$ is a renormalized simulation time. Check if the faster than
# the clock algorithm has produced densities in time that are compatible with this
# formula. You can use this code to produce the analytical data:
#
# ```python
# from scipy.integrate import quad
#
# F = lambda u: quad(lambda v: (1 - np.exp(-v)) / v, 0, u)[0]
# analytic = lambda T: quad(lambda u: np.exp(-2 * F(u)), 0, T)[0]
# x_data = np.logspace(-4, 4, 50)
# y_data = np.vectorize(analytic)(x_data)
# ```

# %%
from scipy.integrate import quad

F = lambda u: quad(lambda v: (1 - np.exp(-v)) / v, 0, u)[0]
analytic = lambda T: quad(lambda u: np.exp(-2 * F(u)), 0, T)[0]
x_data = np.logspace(-4, 4, 50)
y_data = np.vectorize(analytic)(x_data)

plt.semilogx(np.array(times) * 2 * sigma / L, rho, '-r', lw=2)
plt.semilogx(x_data, y_data, '--', lw=2)

plt.ylabel(r'$\rho(t)$', size=20)
plt.xlabel(r'$2\sigma t/L$', size=20)
plt.title("Comparison with theory", fontsize=20);

# %% [markdown]
# ## References
#
# * Rényi, A. "On a One-Dimensional Problem Concerning Random Space-Filling." Publ. Math. Inst. Hung. Acad. Sci. 3, 109-127, 1958
# * Y. Pomeau, Some asymptotic estimates in the random parking problem, J. Phys. A: Math. Gen. 13 L193 (1980)
# * V. Privman, J.-S. Wang, and P. Nielaba, Continuum limit in random sequential adsorption, Phys. Rev. B 43 3366 (1991)
